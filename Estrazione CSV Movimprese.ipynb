# %%
df = pd.read_csv('movimprese_csv (3).csv', sep=';')  # se si tratta di separatore punto e virgola
df.head(20)
# Out:
#     Anno  Trimestre                                            Settore  \
# 0   2024          0                        H Trasporto e magazzinaggio
# 1   2024          0                        H Trasporto e magazzinaggio
# 2   2024          0  E Fornitura di acqua; reti fognarie, attività ...
# 3   2024          0                          C Attività manifatturiere
# 4   2024          0                                      F Costruzioni
# 5   2024          0                                       P Istruzione
# 6   2024          0                      Q Sanità e assistenza sociale
# 7   2024          0                        H Trasporto e magazzinaggio
# 8   2024          0                          C Attività manifatturiere
# 9   2024          0                          C Attività manifatturiere
# 10  2024          0                          C Attività manifatturiere
# 11  2024          0                        H Trasporto e magazzinaggio
# ...

# %%
# Salvataggio in CSV
df.to_csv("movimprese_csv (3).csv", index=False)

print("Dataset generato e salvato come 'Attività imprese 24'.")
# Out:
# Dataset generato e salvato come 'Attività imprese 24'.

# %%
df = pd.read_csv("CSV Attività imprese/movimprese_csv (1).csv", sep=';')  # se si tratta di separatore punto e virgola
df.head(20)
# Out:
#     Anno  Trimestre                                            Settore  \
# 0   2024          0                          C Attività manifatturiere
# 1   2024          0                        H Trasporto e magazzinaggio
# 2   2024          0                          C Attività manifatturiere
# 3   2024          0                          C Attività manifatturiere
# 4   2024          0                                      F Costruzioni
# 5   2024          0  E Fornitura di acqua; reti fognarie, attività ...
# 6   2024          0  E Fornitura di acqua; reti fognarie, attività ...
# 7   2024          0                          C Attività manifatturiere
# 8   2024          0                                      F Costruzioni
# 9   2024          0                          C Attività manifatturiere
# 10  2024          0                          C Attività manifatturiere
# 11  2024          0  M Attività professionali, scientifiche e tecniche
# ...

# %%
df = pd.read_csv("CSV Attività imprese/startup_19052025.csv", sep='|', encoding='latin1')
df.head(10)
# Out:
#                                        denominazione  \
# 0  AUTHENTICON S.R.L.S                           ...
# 1  POLIGLASS SOCIETA' A RESPONSABILITA' LIMITATA ...
# 2  FROG SOCIETA' A RESPONSABILITA' LIMITATA SEMPL...
# 3  SPIN SOCIETA' A RESPONSABILITA' LIMITATA SEMPL...
# 4  PLEIADIS S.R.L.                               ...
# 5  YUK SOCIETA' A RESPONSABILITA' LIMITATA SEMPLI...
# 6  MENDEL CAPITAL S.R.L.                         ...
# 7  INNOVATION DEVELOPMENT ADVANCED SOLUTIONS - I....
# 8  VECAS SOCIETA' A RESPONSABILITA' LIMITATA SEMP...
# 9  ILCOMMERCIALISTAONLINE S.R.L.                 ...
#
#                                        nat.giuridica  codice fiscale   pv  \
# 0  SOCIETA' A RESPONSABILITA' LIMITATA SEMPLIFICA...        963790944  IS
# 1  SOCIETA' A RESPONSABILITA' LIMITATA SEMPLIFICA...        963960943  IS
# 2  SOCIETA' A RESPONSABILITA' LIMITATA SEMPLIFICA...        965760945  IS
# 3  SOCIETA' A RESPONSABILITA' LIMITATA SEMPLIFICA...        965770944  IS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12292 entries, 0 to 12291
# Data columns (total 27 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   denominazione                                       12292 non-null  object
#  1   nat.giuridica                                       12292 non-null  object
#  2   codice fiscale                                      12292 non-null  int64
#  3   pv                                                  11446 non-null  object
#  4   comune                                              12292 non-null  object
#  5   data iscrizione alla sezione delle startup          12292 non-null  object
#  6   data iscrizione al Registro Imprese                 12292 non-null  object
#  7   data inizio dell'esercizio effettivo dell'attività  12292 non-null  object
# ...

# %%
# Salvataggio in CSV
df.to_csv("CSV Attività imprese/startup_19052025.csv", index=False)

print("Dataset generato e salvato come 'Startup Italia'.")
# Out:
# Dataset generato e salvato come 'Startup Italia'.
